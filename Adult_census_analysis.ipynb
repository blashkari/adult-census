# %%
import pandas as pd

# %%
df = pd.read_csv("adult-census.csv")

# %% [markdown]
# # 1. Understanding the Data Frame

# %%
df.head()
# Out:
#    age   workclass      education  education-num       marital-status  \
# 0   25     Private           11th              7        Never-married
# 1   38     Private        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private   Some-college             10   Married-civ-spouse
# 4   18           ?   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                   ?    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country   class
# 0             0              40   United-States   <=50K
# ...

# %%
# To a view a few sample rows in the data frame, to get a better sense of different values in the data

df.sample(10)
# Out:
#        age          workclass      education  education-num  \
# 30643   35       Self-emp-inc        HS-grad              9
# 9278    43          State-gov   Some-college             10
# 10350   35            Private      Assoc-voc             11
# 13060   34            Private      Bachelors             13
# 3209    28          Local-gov   Some-college             10
# 24720   37            Private      Assoc-voc             11
# 31350   23                  ?   Some-college             10
# 40688   52            Private   Some-college             10
# 9057    41   Self-emp-not-inc        HS-grad              9
# 30982   51            Private        HS-grad              9
#
#             marital-status        occupation    relationship    race      sex  \
# 30643   Married-civ-spouse             Sales         Husband   White     Male
# 9278         Never-married     Other-service   Not-in-family   Black   Female
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# class             object
# dtype: object

# %% [markdown]
# **Goal:** Know the non-null count.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
# age               48842 non-null int64
# workclass         48842 non-null object
# education         48842 non-null object
# education-num     48842 non-null int64
# marital-status    48842 non-null object
# occupation        48842 non-null object
# relationship      48842 non-null object
# race              48842 non-null object
# sex               48842 non-null object
# capital-gain      48842 non-null int64
# capital-loss      48842 non-null int64
# hours-per-week    48842 non-null int64
# native-country    48842 non-null object
# class             48842 non-null object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %%
df.count() # Number of non-null values
# Out:
# age               48842
# workclass         48842
# education         48842
# education-num     48842
# marital-status    48842
# occupation        48842
# relationship      48842
# race              48842
# sex               48842
# capital-gain      48842
# capital-loss      48842
# hours-per-week    48842
# native-country    48842
# class             48842
# dtype: int64

# %%
# Selecting one column
workclass = df["workclass"]
unique_workclass = pd.unique(workclass)
print(unique_workclass)
# Out:
# [' Private' ' Local-gov' ' ?' ' Self-emp-not-inc' ' Federal-gov'
#  ' State-gov' ' Self-emp-inc' ' Without-pay' ' Never-worked']

# %%
education = df["education"]
unique_education  = pd.unique(education)
print(unique_education )
# Out:
# [' 11th' ' HS-grad' ' Assoc-acdm' ' Some-college' ' 10th' ' Prof-school'
#  ' 7th-8th' ' Bachelors' ' Masters' ' Doctorate' ' 5th-6th' ' Assoc-voc'
#  ' 9th' ' 12th' ' 1st-4th' ' Preschool']

# %%
# Selecting multiple column
columns = ["workclass","education"]
df[columns].sample(5)
# Out:
#                workclass      education
# 17715          State-gov   Some-college
# 33079                  ?        HS-grad
# 24608          State-gov    Prof-school
# 10797            Private      Bachelors
# 8551    Self-emp-not-inc            9th

# %% [markdown]
# # 2. Core Descriptive Statistics

# %%
numerical_columns = ["age","hours-per-week","capital-gain","capital-loss"]

# %%
df[numerical_columns].describe()
# Out:
#                 age  hours-per-week  capital-gain  capital-loss
# count  48842.000000    48842.000000  48842.000000  48842.000000
# mean      38.643585       40.422382   1079.067626     87.502314
# std       13.710510       12.391444   7452.019058    403.004552
# min       17.000000        1.000000      0.000000      0.000000
# 25%       28.000000       40.000000      0.000000      0.000000
# 50%       37.000000       40.000000      0.000000      0.000000
# 75%       48.000000       45.000000      0.000000      0.000000
# max       90.000000       99.000000  99999.000000   4356.000000

# %% [markdown]
# ** Goal:** Count and visualize distributions of `age` and `hours-per-week`

# %%
age = df["age"]

# %% [markdown]
# To visuliza the distribution we can use the method `.hist()`

# %%
age.hist(bins = 15, color = 'skyblue', edgecolor = 'black', grid = False, alpha = 0.7)

# %%
hours_per_week = df["hours-per-week"]
hours_per_week.hist(bins = 15, color = 'skyblue', edgecolor = 'black', grid = False, alpha = 0.7)

# %%
capital_gain = df["capital-gain"]
_ = capital_gain.hist(bins = 10, color = 'skyblue', edgecolor = 'black', grid = False, alpha = 0.7)

# %% [markdown]
# # 3. Sorting

# %% [markdown]
# ** Goal:** Sort the respondents by age, olsedt to youngest

# %%
df_sorted_by_age = df.sort_values(by = "age", ascending = False)

# %%
df_sorted_by_age.head(10)
# Out:
#        age   workclass     education  education-num       marital-status  \
# 40519   90           ?       1st-4th              2              Widowed
# 21553   90     Private           9th              5        Never-married
# 47977   90           ?       HS-grad              9   Married-civ-spouse
# 21651   90   Local-gov       Masters             14   Married-civ-spouse
# 41584   90           ?       7th-8th              4            Separated
# 11871   90           ?          10th              6             Divorced
# 29256   90     Private          10th              6   Married-civ-spouse
# 28012   90           ?       HS-grad              9              Widowed
# 25087   90     Private   Prof-school             15   Married-civ-spouse
# 6976    90     Private       HS-grad              9   Married-civ-spouse
#
#               occupation    relationship    race      sex  capital-gain  \
# 40519                  ?   Not-in-family   Black   Female             0
# ...

# %% [markdown]
# ** Goal:** Investigate the people who have the highets capital_gain for each age

# %%
# Sort by age descending, then hours-per-week descending
columns = ["age","hours-per-week"]
order = [False, False]
sorted_by_age_hours = df.sort_values(by=columns, ascending = order)

# %%
sorted_by_age_hours.head(10)
# Out:
#        age          workclass     education  education-num  \
# 8427    90        Federal-gov       Masters             14
# 31637   90            Private       HS-grad              9
# 25087   90            Private   Prof-school             15
# 3496    90   Self-emp-not-inc   Prof-school             15
# 21651   90          Local-gov       Masters             14
# 28277   90            Private     Bachelors             13
# 899     90            Private    Assoc-acdm             12
# 21687   90            Private       Masters             14
# 22513   90   Self-emp-not-inc     Bachelors             13
# 26826   90            Private       HS-grad              9
#
#             marital-status         occupation    relationship    race    sex  \
# 8427              Divorced     Prof-specialty   Not-in-family   White   Male
# 31637              Widowed   Transport-moving       Unmarried   White   Male
# 25087   Married-civ-spouse     Prof-specialty         Husband   White   Male
# ...

# %% [markdown]
# # 4. Filtering

# %%
unique_genders = pd.unique(df["sex"])
print(unique_genders)
# Out:
# [' Male' ' Female']

# %% [markdown]
# Create a filtered dataset with only females. Notice the white space before ' Male' and ' Female'

# %%
female_respondents = df[df["sex"]==' Female']
female_respondents.head(10)
# Out:
#     age          workclass      education  education-num       marital-status  \
# 4    18                  ?   Some-college             10        Never-married
# 8    24            Private   Some-college             10        Never-married
# 12   26            Private        HS-grad              9        Never-married
# 17   43            Private        HS-grad              9   Married-civ-spouse
# 18   37            Private        HS-grad              9              Widowed
# 21   34            Private   Some-college             10        Never-married
# 22   72                  ?        7th-8th              4             Divorced
# 31   56   Self-emp-not-inc           11th              7              Widowed
# 34   26            Private        HS-grad              9             Divorced
# 45   28            Private      Assoc-voc             11   Married-civ-spouse
#
#             occupation    relationship    race      sex  capital-gain  \
# ...

# %%
len(female_respondents)/len(df)*100
# Out:
# 33.151795585766344

# %% [markdown]
# ** Goal: ** Look at the histogram of female respondants

# %%
female_respondents["age"].hist(bins = 20, color = 'skyblue', edgecolor = 'black', grid = False, alpha = 0.7)

# %% [markdown]
# The histogram is right skewed.

# %% [markdown]
# ** Goal: ** Next, we want to select rows where hour-per-week is greater than 40.

# %%
above_40_respondents = df[df["hours-per-week"] > 40]

# %% [markdown]
# Visualize the histogram of 'above_40_respondents' by 'age'.

# %%
above_40_respondents["age"].hist(bins = 20, color = 'skyblue', edgecolor = 'black', grid = False, alpha = 0.7)
age.hist(bins = 20, color = 'skyblue', edgecolor = 'black', grid = False, alpha = 0.3)

# %% [markdown]
# Goal: We want to run analysis for individuals who are female and hours-per-week above 40
